# %%
# Data Analysis of the C-MAPSSS DATASET

# %%
# import necessery package
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('inputData/Train_FD003.csv')
df1.describe()
# Out:
#             UNIT_ID      CYCLE_ID   CONDITION_1   CONDITION_2  CONDITION_3  \
# count  24720.000000  24720.000000  24720.000000  24720.000000      24720.0
# mean      48.631877    139.077063     -0.000024      0.000005        100.0
# std       29.348985     98.846675      0.002194      0.000294          0.0
# min        1.000000      1.000000     -0.008600     -0.000600        100.0
# 25%       23.000000     62.000000     -0.001500     -0.000200        100.0
# 50%       47.000000    124.000000      0.000000     -0.000000        100.0
# 75%       74.000000    191.000000      0.001500      0.000300        100.0
# max      100.000000    525.000000      0.008600      0.000700        100.0
#
#           SENSOR_01     SENSOR_02     SENSOR_03     SENSOR_04     SENSOR_05  \
# count  2.472000e+04  24720.000000  24720.000000  24720.000000  2.472000e+04
# mean   5.186700e+02    642.457858   1588.079175   1404.471212  1.462000e+01
# std    6.684921e-11      0.523031      6.810418      9.773178  3.602525e-12
# min    5.186700e+02    640.840000   1564.300000   1377.060000  1.462000e+01
# 25%    5.186700e+02    642.080000   1583.280000   1397.187500  1.462000e+01
# 50%    5.186700e+02    642.400000   1587.520000   1402.910000  1.462000e+01
# 75%    5.186700e+02    642.790000   1592.412500   1410.600000  1.462000e+01
# max    5.186700e+02    645.110000   1615.390000   1441.160000  1.462000e+01
#
#            ...          SENSOR_13     SENSOR_14     SENSOR_15     SENSOR_16  \
# count      ...       24720.000000  24720.000000  24720.000000  2.472000e+04
# mean       ...        2388.071643   8144.202916      8.396176  3.000000e-02
# std        ...           0.158121     16.504118      0.060512  1.750371e-14
# min        ...        2386.930000   8099.680000      8.156300  3.000000e-02
# 25%        ...        2388.010000   8134.510000      8.360600  3.000000e-02
# 50%        ...        2388.070000   8141.200000      8.398300  3.000000e-02
# 75%        ...        2388.140000   8149.230000      8.437000  3.000000e-02
# max        ...        2388.610000   8290.550000      8.570500  3.000000e-02
#
#           SENSOR_17  SENSOR_18  SENSOR_19     SENSOR_20     SENSOR_21  \
# count  24720.000000    24720.0    24720.0  24720.000000  24720.000000
# mean     392.566545     2388.0      100.0     38.988552     23.393024
# std        1.761459        0.0        0.0      0.248865      0.149234
# min      388.000000     2388.0      100.0     38.170000     22.872600
# 25%      391.000000     2388.0      100.0     38.830000     23.296200
# 50%      392.000000     2388.0      100.0     38.990000     23.391600
# 75%      394.000000     2388.0      100.0     39.140000     23.483300
# max      399.000000     2388.0      100.0     39.850000     23.950500
#
#                 RUL
# count  24720.000000
# mean     138.077063
# std       98.846675
# min        0.000000
# 25%       61.000000
# 50%      123.000000
# 75%      190.000000
# max      524.000000
#
# [8 rows x 27 columns]

# %%
df_100 = df1[df1['UNIT_ID']==1]

# %%
# Analysis based on RUL

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,80))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['RUL'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 1

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,60))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_1'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 2

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,60))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_2'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 3

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,60))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_3'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()
