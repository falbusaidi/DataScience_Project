# %%
# Data Analysis of the C-MAPSSS DATASET

# %%
# import necessery package
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('inputData/Train_FD002_Kincked.csv')
df1.describe()
# Out:
#             UNIT_ID      CYCLE_ID   CONDITION_1   CONDITION_2   CONDITION_3  \
# count  53759.000000  53759.000000  53759.000000  53759.000000  53759.000000
# mean     131.082981    109.154746     23.998407      0.572056     94.046020
# std       74.463862     69.180569     14.747376      0.310016     14.237735
# min        1.000000      1.000000      0.000000      0.000000     60.000000
# 25%       68.000000     52.000000     10.004600      0.250700    100.000000
# 50%      131.000000    104.000000     25.001300      0.700000    100.000000
# 75%      195.000000    157.000000     41.998000      0.840000    100.000000
# max      260.000000    378.000000     42.008000      0.842000    100.000000
#
#           SENSOR_01     SENSOR_02     SENSOR_03     SENSOR_04     SENSOR_05  \
# count  53759.000000  53759.000000  53759.000000  53759.000000  53759.000000
# mean     472.910207    579.672399   1419.971013   1205.442024      8.031986
# ...

# %%
#df_100 = df1[df1['UNIT_ID']==1]
df_100 = df1[df1['UNIT_ID']==1]

# %%
grp = df1.groupby('UNIT_ID').last()['CYCLE_ID']
grp.max()
# Out:
# 378

# %%
grp.min()
# Out:
# 128

# %%
grp.mean()
# Out:
# 206.76538461538462

# %%
grp.std()
# Out:
# 46.78219839558725

# %%
# Analysis based on RUL

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,80))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].plot(df_100['CYCLE_ID'],df_100[index])
    axes[i-1].set_xlabel('CYCLE_ID')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 1

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,80))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_1'],df_100[index])
    axes[i-1].set_xlabel('CONDITION_1')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 2

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,80))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_2'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
# analysis based on operating condistion 3

fig, axes = plt.subplots(nrows=21,ncols=1, figsize=(6,80))

for i in range(1,22):
    if i < 10:
        index='SENSOR_0'+str(i)
    else:
        index='SENSOR_'+str(i)
    axes[i-1].scatter(df_100['CONDITION_3'],df_100[index])
    axes[i-1].set_xlabel('RUL')
    axes[i-1].set_ylabel(index)
fig.tight_layout()

# %%
plt.scatter(df_100['CONDITION_3'],df_100.iloc[:,3:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6a4c80ac6c1f> in <module>()
# ----> 1 plt.scatter(df_100['CONDITION_3'],df_100.iloc[:,3:])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...
